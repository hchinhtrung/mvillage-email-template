# %% [markdown]
# # 🏨 AGODA Price Crawler
#
# Chạy lần lượt các cell từ trên xuống: **① Cấu hình → ② Đọc input → ③ Crawl → ④ Xem kết quả**.
#
# **Đổi nguồn input:** sửa `INPUT_MODE` ở cell ① — `"gsheet"` (Google Sheet online) hoặc `"offline"` (file CSV/XLSX trên máy).
#
# **Format file offline:** chỉ cần **3 cột đầu theo đúng thứ tự** `hotel_name, hotel_url, room_type` (tên cột không quan trọng, chỉ cần đúng thứ tự). Có file mẫu ở `input/TEMPLATE_hotels.csv`.
#
# **Output** nằm trong `results/agoda/<RUN_NAME>/` — mỗi notebook 1 thư mục riêng (đặt `RUN_NAME` ở cell ①, mỗi notebook 1 tên khác nhau để không ghi đè lẫn nhau):
# - `FINAL_<YYYYMMDD>.csv` — kết quả cuối
# - `TEMP_agoda.csv` — checkpoint: lỡ tắt giữa chừng, chạy lại cell ③ sẽ tự resume phần chưa xong — hotel **chưa từng cào** sẽ chạy trước, hotel còn NA/SOLD OUT retry sau
#
# Cache warm (`results/agoda/captures/`) vẫn dùng chung giữa các notebook nên không tốn thêm thời gian warm.

# %%
# ════════════════ ① CẤU HÌNH ════════════════

# ── Tên run: kết quả nằm RIÊNG trong results/agoda/<RUN_NAME>/ ──
# ⚠️ Mỗi notebook phải đặt 1 tên KHÁC nhau (notebook này "run1", notebook kia "run2")
RUN_NAME = "run1"

# ── Nguồn input: "gsheet" (online) hoặc "offline" (file trên máy) ──
INPUT_MODE = "gsheet"

# Dùng khi INPUT_MODE = "gsheet" (gid của tab được tự lấy từ URL)
GSHEET_URL = "https://docs.google.com/spreadsheets/d/1EauwTNOMVMBT_CUHwf4EtOz1nsZAjG2SJ_LEh199N0Q/edit?gid=1289817800#gid=1289817800"

# Dùng khi INPUT_MODE = "offline" — đường dẫn tuyệt đối, hoặc tương đối so với 31.crawl-tool
# ⚠️ File phải có 3 cột đầu là (tên KS, URL, loại phòng) — file "TEMP_*" là checkpoint OUTPUT, không phải input!
OFFLINE_FILE = "input/v"

# ── Tham số crawl ──
WEEKS      = 6      # số tuần cần crawl
MAX_HOTELS = 0      # 0 = crawl tất cả; đặt 5 để test nhanh 5 khách sạn đầu
SHARD      = ""     # "" = không chia; "1/3" = chạy phần 1 trong 3 phần (chạy lần lượt 1/3, 2/3, 3/3)

# %%
# ════════════════ ② ĐỌC INPUT ════════════════
import os, sys

if "ROOT" not in globals():                    # giữ nguyên ROOT khi chạy lại cell
    ROOT = os.path.abspath("")                 # .../31.crawl-tool (nơi đặt notebook này)
assert os.path.isdir(os.path.join(ROOT, "crawler")), (
    f"Không tìm thấy package `crawler` trong {ROOT} — hãy mở notebook từ thư mục 31.crawl-tool")
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

import crawler
from crawler.hotels_io import read_hotels

if INPUT_MODE == "gsheet":
    INPUT = GSHEET_URL
    print("📡 Input: Google Sheet online")
else:
    INPUT = OFFLINE_FILE if os.path.isabs(OFFLINE_FILE) else os.path.join(ROOT, OFFLINE_FILE)
    assert os.path.exists(INPUT), f"Không tìm thấy file: {INPUT}"
    print(f"📁 Input: file offline — {INPUT}")

hotels = read_hotels(INPUT)
print(f"✅ Đọc được {len(hotels)} khách sạn. 5 dòng đầu:")
for name, url, room in hotels[:5]:
    print(f"   • {name} — {room}")
# Out:
# 📡 Input: Google Sheet online
# ✅ Đọc được 157 khách sạn. 5 dòng đầu:
#    • Almanty - Junior Suite — Junior Suite
#    • Almanty - Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Bể Bơi (Superior Pool Double or Twin) — Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Bể Bơi (Superior Pool Double or Twin)
#    • Almanty - Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Thị Trấn (Superior Town Double or Twin) — Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Thị Trấn (Superior Town Double or Twin)
#    • Almanty - Phòng Đôi hoặc Hai Giường Đơn có Gác Xép (Loft Room Double or Twin) — Phòng Đôi hoặc Hai Giường Đơn có Gác Xép (Loft Room Double or Twin)
#    • Almanty - Phòng Đôi hoặc Hai Giường Đơn Loại Sang Hướng Bể Bơi (Deluxe Pool Double or Twin) — Phòng Đôi hoặc Hai Giường Đơn Loại Sang Hướng Bể Bơi (Deluxe Pool Double or Twin)

# %%
# (TÙY CHỌN) Tải Google Sheet về file offline — lần sau chỉ cần đổi INPUT_MODE = "offline"
import pandas as pd
from crawler.hotels_io import _gsheet_url

os.makedirs(os.path.join(ROOT, "input"), exist_ok=True)
dest = os.path.join(ROOT, "input", "agoda_hotels.csv")
pd.read_csv(_gsheet_url(GSHEET_URL)).to_csv(dest, index=False, encoding="utf-8-sig")
print(f"💾 Đã lưu bản offline: {dest}")
# Out:
# 💾 Đã lưu bản offline: /Users/hchinhtrung/Documents/GitHub/mvillage-email-template/31.crawl-tool/input/agoda_hotels.csv

# %%
# ════════════════ ③ CRAWL ════════════════
OUTDIR = os.path.join(ROOT, "results", "agoda", RUN_NAME)   # mỗi notebook 1 thư mục kết quả riêng
os.makedirs(OUTDIR, exist_ok=True)
os.chdir(OUTDIR)                     # output (FINAL_*.csv, TEMP_agoda.csv) nằm ở đây

kwargs = dict(
    site="agoda",                    # direct replay (nhanh) + Camoufox warm
    input=INPUT,
    weeks=WEEKS,
    # cache warm dùng CHUNG cho mọi notebook (đỡ warm lại) — chỉ kết quả là tách riêng
    capture_dir=os.path.join(ROOT, "results", "agoda", "captures"),
)
if MAX_HOTELS:
    kwargs["max"] = MAX_HOTELS
if SHARD:
    kwargs["shard"] = SHARD

await crawler.arun(**kwargs)         # notebook cho phép await trực tiếp
# Out:
# 📂 Resume: 157 rows from TEMP_agoda.csv
# 🚀 AGODA crawl | 157 hotels × 6w | direct+fallback | engine=camoufox | W1=2026-07-21
# ✔️  1/157 Almanty - Junior Suite — complete, skip
# ✔️  2/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Bể Bơi (Superior Pool Double or Twin) — complete, skip
# ✔️  3/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Thị Trấn (Superior Town Double or Twin) — complete, skip
# ✔️  4/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn có Gác Xép (Loft Room Double or Twin) — complete, skip
# ✔️  5/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn Loại Sang Hướng Bể Bơi (Deluxe Pool Double or Twin) — complete, skip
# ✔️  6/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn Loại Sang Hướng Thị Trấn (Deluxe Town Double or Twin) — complete, skip
# ✔️  7/157 Almanty - Suite có Bồn Sục Trên Tầng Thượng (Rooftop Jacuzzi Suite) — complete, skip
# ✔️  8/157 Almanty - Suite Giường Lớn hoặc Hai Giường Đơn Thương Gia (Executive Suite King or Twin) — complete, skip
# ✔️  9/157 Almanty - Suite Tổng thống (Presidental Suite) — complete, skip
# ✔️  10/157 Ana Mandara Villas Dalat Resort & Spa — complete, skip
# ✔️  11/157 Ancient Huế Garden Houses (Ancient Hue Garden Houses) — complete, skip
# ✔️  12/157 Au Lac Charner — complete, skip
# ✔️  13/157 Au Lac Charner — complete, skip
# ✔️  14/157 Avana Retreat — complete, skip
# ✔️  15/157 Bach Place Dalat — complete, skip
# ✔️  16/157 Bakhan Village Resort — complete, skip
# ✔️  17/157 Ban la - Attic Deluxe Room (Attic Deluxe Room) — complete, skip
# ✔️  18/157 Ban la - Deluxe giường đôi có cửa sổ (Deluxe Double with Window) — complete, skip
# ✔️  19/157 Ban la - Phòng cổ điển giường đôi (Classic Double Room) — complete, skip
# ✔️  20/157 Ban la - Phòng có giường cỡ King nhìn ra cảnh núi non (King Room with Mountain View) — complete, skip
# ✔️  21/157 Ban la - Phòng Deluxe Giường Đôi Có Bồn Tắm (Deluxe Double Room with Bath) — complete, skip
# ✔️  22/157 Ban la - Phòng Executive giường đôi (Executive Double Room) — complete, skip
# ✔️  23/157 Ban la - Phòng Giường Đôi Lớn Loại Sang (Deluxe Queen Room) — complete, skip
# ✔️  24/157 Ban la - Phòng Hai Giường Đơn Loại Sang (Deluxe Twin Room) — complete, skip
# ✔️  25/157 Ban la - Phòng Hạng Sang Giường Đôi (Elite Double Room) — complete, skip
# ✔️  26/157 Ban la - Phòng Loại Sang Giường Đôi Có Ban Công Và Bồn Tắm (Deluxe Double Room with Balcony and Bathtub) — complete, skip
# ✔️  27/157 Ban la - Phòng Suite Hướng núi (Suite Mountain View) — complete, skip
# ✔️  28/157 Ban la - Phòng Superior giường đôi lớn (Superior Queen Room) — complete, skip
# ✔️  29/157 Ban la - Phòng Thương Hiệu (Signature Room) — complete, skip
# ✔️  30/157 Ban la - Phòng Tiêu Chuẩn Giường Đôi (Standard Double Room) — complete, skip
# ✔️  31/157 Banla Boutique Hotel — complete, skip
# ✔️  32/157 Becamex Hotel New City — complete, skip
# ✔️  33/157 Citadines Central Binh Duong — complete, skip
# ✔️  34/157 Colline Dalat — complete, skip
# ✔️  35/157 Dechiu Hotel - Hotel — complete, skip
# ✔️  36/157 Dechiu Hotel 1 - Hotel — complete, skip
# ✔️  37/157 ENSO Retreat Hoi An - Rediscovery & Serenity — complete, skip
# ✔️  38/157 Fairfield by Marriott South Binh Duong — complete, skip
# ✔️  39/157 Goldient Boutique Hotel DaLat - Căn hộ sang trọng (Luxury Apartment) — complete, skip
# ✔️  40/157 Goldient Boutique Hotel DaLat - Phòng Cao Cấp Cho Hai Người (Superior Double Room) — complete, skip
# ✔️  41/157 Goldient Boutique Hotel DaLat - Phòng Corner giường đôi - Không hút thuốc (Corner Double Room - Non-Smoking) — complete, skip
# ✔️  42/157 Goldient Boutique Hotel DaLat - Phòng Deluxe 2 Giường Đơn Có Ban Công (Deluxe Twin with Balcony) — complete, skip
# ✔️  43/157 Goldient Boutique Hotel DaLat - Phòng Deluxe 3 người có ban công (Deluxe Triple Room with balcony) — complete, skip
# ✔️  44/157 Goldient Boutique Hotel DaLat - Phòng Deluxe Giường Đôi với Ban công (Deluxe Double with Balcony) — complete, skip
# ✔️  45/157 Goldient Boutique Hotel DaLat - Phòng Loại Sang Hướng Bể Bơi (Deluxe Pool View) — complete, skip
# ✔️  46/157 Goldient Boutique Hotel DaLat - Phòng Premium Giường đôi (Premium Double Room) — complete, skip
# ✔️  47/157 Goldient Boutique Hotel DaLat - Phòng Superior 2 giường (Superior Twin Room) — complete, skip
# ✔️  48/157 Goldient Boutique Hotel DaLat - Suite Executive có Ban công (Executive Suite with Balcony) — complete, skip
# ✔️  49/157 Goldient Boutique Hotel DaLat - Suite Junior Có Ban Công (Junior Suite with Balcony) — complete, skip
# ✔️  50/157 Grand Hoi An - Biệt Thự Signature (Signature Villa) — complete, skip
# ✔️  51/157 Grand Hoi An - Biệt Thự Suite Junior Có Sân Hiên (Villa Junior Suite with Terrace) — complete, skip
# ✔️  52/157 Grand Hoi An - Biệt Thự Suite Lớn 2 Giường Đơn Hướng Vườn Có Sân Hiên Hoặc Ban Công (Villa Grand Suite Twin Garden View with Terrace or Balcony) — complete, skip
# ✔️  53/157 Grand Hoi An - Signature Villa Premier Room with Terrace — complete, skip
# ✔️  54/157 Grand Hoi An - Signature Villa Suite with Pool Access — complete, skip
# ✔️  55/157 Grand Hoi An - Villa Deluxe Room with Balcony — complete, skip
# ✔️  56/157 Grand Hoi An - Villa Premier Room Pool View with Balcony — complete, skip
# ✔️  57/157 Grand Hoi An - Villa Premier Room with Balcony — complete, skip
# ✔️  58/157 Grand Hoi An - Villa Premier Room with Terrace — complete, skip
# ✔️  59/157 Grand Hoi An - Villa Suite with Terrace — complete, skip
# ✔️  60/157 Harvest Day Hoi An - Hotel — complete, skip
# ✔️  61/157 Hato — complete, skip
# ✔️  62/157 Hato — complete, skip
# ✔️  63/157 HIIVE by fusion Binh Duong - VSIP 1 — complete, skip
# ✔️  64/157 Hoi An Beach Resort — complete, skip
# ✔️  65/157 Hotel de la Coupole - MGallery — complete, skip
# ✔️  66/157 KK Sapa Hotel — complete, skip
# ✔️  67/157 KOI Resort and Spa Hoi An — complete, skip
# ✔️  68/157 La siesta - Khu Club 2 tầng Suite có ban công (Club Wing Duplex Suite with Balcony) — complete, skip
# ✔️  69/157 La siesta - Khu Club cao cấp Suite có ban công (Club Wing Premium Suite with Terrace) — complete, skip
# ✔️  70/157 La siesta - Khu Club hướng hồ bơi Varanda Suite (Club Wing Pool View Veranda Suite) — complete, skip
# ✔️  71/157 La siesta - Khu Club Junior Suite có ban công (Club Wing Junior Suite with Balcony) — complete, skip
# ✔️  72/157 La siesta - Khu Cổ điển Grand Suite (Classic Wing Grand Suite) — complete, skip
# ✔️  73/157 La siesta - Khu Cổ điển Phòng Deluxe (Classic Wing Deluxe Room) — complete, skip
# ✔️  74/157 La siesta - Khu Cổ điển Phòng Gia đình (Classic Wing Family Room) — complete, skip
# ✔️  75/157 La siesta - La Siesta Suite — complete, skip
# ✔️  76/157 La siesta - Phòng Đôi Loại Sang Phía Cổ Điển có Ban Công (Classic Wing Deluxe Double Room with Balcony) — complete, skip
# ✔️  77/157 La siesta - Phòng Hai Giường Đơn Loại Sang Phía Cổ Điển có Ban Công (Classic Wing Deluxe Twin Room with Balcony) — complete, skip
# ✔️  78/157 La siesta - Suite — complete, skip
# ✔️  79/157 La siesta - Suite Hai Tầng Thương Gia Phía Hội Viên có Ban Công (Club Wing Executive Duplex Suite with Balcony) — complete, skip
# ✔️  80/157 La siesta - Suite La Siesta - Cánh Cổ Điển (La Siesta Suite - Classic Wing) — complete, skip
# ✔️  81/157 La siesta - Suite Lớn Phía Hội Viên Hướng Bể Bơi (Club Wing Executive Pool View Suite) — complete, skip
# ✔️  82/157 La Siesta Hoi An Resort & Spa — complete, skip
# ✔️  83/157 La Siesta Hoi An Resort & Spa 1 — complete, skip
# ✔️  84/157 Le Récit - Deluxe giường đôi (Deluxe Double) — complete, skip
# ✔️  85/157 Le Récit - Penthouse — complete, skip
# ✔️  86/157 Le Récit - Phòng Deluxe 2 Giường đơn (Deluxe Twin) — complete, skip
# ✔️  87/157 Le Récit - Suite Căn Hộ Áp Mái 1 Phòng Ngủ (Penthouse 1 Bedroom Suite) — complete, skip
# ✔️  88/157 Le Récit - Suite dạng Căn hộ áp mái 2 Phòng ngủ (Penthouse 2 Bedroom Suite) — complete, skip
# ✔️  89/157 Le Récit - Suite Deluxe (Deluxe Suite) — complete, skip
# ✔️  90/157 Le Récit - Suite Giường Lớn (King Suite) — complete, skip
# ✔️  91/157 Le Recit Boutique Hotel de Dalat — complete, skip
# ✔️  92/157 Legacy Mekong — complete, skip
# ✔️  93/157 M Hotel — complete, skip
# ✔️  94/157 Mai Chau Ecolodge — complete, skip
# ✔️  95/157 Mit Retreat — complete, skip
# ✔️  96/157 Mơ Stay - Forest Resort — complete, skip
# ✔️  97/157 Moire Hội An -1 King Premium River View — complete, skip
# ✔️  98/157 Moire Hội An -1 King Premium Terrace Access — complete, skip
# ✔️  100/157 Moire Hội An -2 Twin Deluxe River View — complete, skip
# ✔️  101/157 Moire Hội An -Moire Pool Villa — complete, skip
# ✔️  102/157 Moire Hội An -Phòng Deluxe có 2 giường đơn (2 Twin Deluxe) — complete, skip
# ✔️  104/157 Moire Hội An -Phòng Deluxe có giường King (1 King Deluxe) — complete, skip
# ✔️  105/157 Moire Hội An -Phòng Loại Sang (Deluxe Room) — complete, skip
# ✔️  108/157 Mùa Dalat Wellness Hotel — complete, skip
# ✔️  109/157 MV Hotel Hoi An - Deluxe giường King có ban công (Deluxe King with Balcony) — complete, skip
# ✔️  110/157 MV Hotel Hoi An - Deluxe King Pool View with Balcony — complete, skip
# ✔️  111/157 MV Hotel Hoi An - Duplex City View with Balcony — complete, skip
# ✔️  112/157 MV Hotel Hoi An - Grand Suite 1 Bedroom — complete, skip
# ✔️  113/157 MV Hotel Hoi An - Phòng Deluxe 2 Giường đơn với Ban công (Deluxe Twin Beds with Balcony) — complete, skip
# ✔️  114/157 MV Hotel Hoi An - Phòng Loại Sang Hướng Bể Bơi 2 Giường Đơn (Deluxe Twin Pool View) — complete, skip
# ✔️  115/157 Nexus House An Son Da Lat — complete, skip
# ✔️  116/157 Palm Garden Beach Resort & Spa — complete, skip
# ✔️  117/157 Pao's Sapa Leisure Hotel — complete, skip
# ✔️  118/157 Renaissance Danang Hoi An Resort & Spa — complete, skip
# ✔️  119/157 Reu Boutique Hotel - Hotel — complete, skip
# ✔️  120/157 Sapa Jade Hill Resort & Spa — complete, skip
# ✔️  121/157 Sheraton Can Tho — complete, skip
# ✔️  122/157 Silk Path Grand Sapa Resort & Spa — complete, skip
# ✔️  123/157 Silverland Ben Thanh_Spring Field - No Window — complete, skip
# ✔️  124/157 Silverland Ben Thanh_Sunshine Garden - Double or Twin — complete, skip
# ✔️  125/157 Sol An Bang Beach Resort & Spa — complete, skip
# ✔️  126/157 Sứ Retreat Hoi An - Riverfront Resort — complete, skip
# ✔️  127/157 Swiss-Belresort Tuyen Lam Dalat — complete, skip
# ✔️  128/157 Terracotta Hotel and Resort Dalat — complete, skip
# ✔️  129/157 The Mist Boutique - Deluxe City View — complete, skip
# ✔️  130/157 The Mist Boutique - Deluxe Mountain View — complete, skip
# ✔️  131/157 The Mist Boutique - Double Room — complete, skip
# ✔️  132/157 The Mist Boutique - Executive Suite — complete, skip
# ✔️  133/157 The Mist Boutique - Signature Suite — complete, skip
# ✔️  134/157 The Mist Boutique - Suite City View Room — complete, skip
# ✔️  135/157 The Mist Boutique - Suite Mountain View — complete, skip
# ✔️  136/157 The Mist Boutique - Tripple Balcony — complete, skip
# ✔️  137/157 The Mist Boutique - Tripple Deluxe — complete, skip
# ✔️  138/157 The Pink Boutique Hotel — complete, skip
# ✔️  139/157 The Signature Hoi An — complete, skip
# ✔️  140/157 Topas Ecolodge — complete, skip
# ✔️  141/157 Tui ba gang - Deluxe Plus — complete, skip
# ✔️  142/157 Tui ba gang - Phòng Đẳng Cấp – 1 Giường (Premier Room - 1 Bed) — complete, skip
# ✔️  143/157 Tui ba gang - Phòng Gia Đình Loại Sang (Deluxe Family Room) — complete, skip
# ✔️  144/157 Tui ba gang - Phòng Gia đình với Ban công Riêng (Family Room with Private Balcony) — complete, skip
# ✔️  145/157 Tui ba gang - Phòng Loại Sang - 1 Giường (Deluxe Room -- 1 Bed) — complete, skip
# ✔️  146/157 Tui ba gang - Phòng Trip (Trip Room) — complete, skip
# ✔️  147/157 Túi Ba Gang Central Hotel — complete, skip
# ✔️  148/157 Vedana Lagoon Wellness Resort & Spa - 2 Bedrooms Lagoon View Villa with Free Afternoon Cocktail — complete, skip
# ✔️  149/157 Vedana Lagoon Wellness Resort & Spa - Biệt Thự Hồ Bơi 2 Phòng Ngủ Hướng Đầm Phá - Miễn Phí Cocktail Buổi Chiều (2 Bedrooms Lagoon View Pool Villa - Free afternoon cocktail) — complete, skip
# ✔️  150/157 Vedana Lagoon Wellness Resort & Spa - Biệt Thự Trên Mặt Nước Có Hồ Bơi - Cocktail Chiều Miễn Phí (Water Pool Villa - Free afternoon cocktail) — complete, skip
# ✔️  151/157 Vedana Lagoon Wellness Resort & Spa - Hillside Biệt thự Có hồ bơi (Hillside Pool Villa) — complete, skip
# ✔️  152/157 Vedana Lagoon Wellness Resort & Spa - Villa bên hồ (Water Villa) — complete, skip
# ✔️  153/157 Vedana Lagoon Wellness Resort & Spa - Villa cạnh đồi (Hillside Villa) — complete, skip
# ✔️  154/157 Victoria Hoi An Beach Resort & Spa — complete, skip
# ✔️  155/157 Ville De Mont Mountain Resort — complete, skip
# ✔️  156/157 Wink — complete, skip
#
# 🏨 99/157 Moire Hội An -1 King Suite River View | 1 King Suite River View | need weeks [6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 1, fallback 0) | pace limit=3
#
# 🏨 103/157 Moire Hội An -Phòng Deluxe có giường King - Phù hợp cho người khuyết tật (1 King Deluxe Accessible) | Phòng Deluxe có giường King - Phù hợp cho người khuyết tật (1 King Deluxe Accessible) | need weeks [3, 4]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 2, fallback 0) | pace limit=4
#
# 🏨 106/157 Moire Hội An -Phòng Loại Sang 1 Giường Lớn Hướng Sông (1 King Deluxe River View) | Phòng Loại Sang 1 Giường Lớn Hướng Sông (1 King Deluxe River View) | need weeks [6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 1, fallback 0) | pace limit=4
#
# 🏨 107/157 Moire Hoi An Vignette Collection By IHG | 1 King Deluxe | need weeks [5]
#    ✅ 6/6 priced (direct 1, fallback 0) | pace limit=4
#
# 🏨 157/157 Wink | 2 Twin Beds | need weeks [2]
#       🚫 [Wink] W2: SOLD OUT
#    ⚠️ 5/6 priced (direct 0, fallback 1) | pace limit=1
#
# 🔄 Round 2: 1 cells / 1 hotels still NA/SOLD OUT — browser retry…
#       ✅ [Wink] W2: 1,300,000 (08/01, 2 Twin Beds)
#    🔄 Round 2 done: 1 cells recovered
#
# ============================================================
# ✅ FINAL_20260716.csv | priced 942/942 (100.0%) | 🚫 0 SO | ❌ 0 NA
# ⏱️ 2m 17s for 157 hotels × 6w
# ============================================================
# 'FINAL_20260716.csv'

# %%
# ════════════════ ④ XEM KẾT QUẢ ════════════════
import glob
import pandas as pd

OUTDIR = os.path.join(ROOT, "results", "agoda", RUN_NAME)
files = sorted(glob.glob(os.path.join(OUTDIR, "FINAL_*.csv")))
assert files, "Chưa có file FINAL nào — hãy chạy cell ③ trước."
latest = files[-1]
df = pd.read_csv(latest)
print(f"📄 {latest} — {len(df)} dòng")
df.head(20)
# Out:
# 📄 /Users/hchinhtrung/Documents/GitHub/mvillage-email-template/31.crawl-tool/results/agoda/run1/FINAL_20260716.csv — 157 dòng
#                                       hotel_name  \
# 0                     Harvest Day Hoi An - Hotel
# 1                     Reu Boutique Hotel - Hotel
# 2         Renaissance Danang Hoi An Resort & Spa
# 3             Victoria Hoi An Beach Resort & Spa
# 4                      KOI Resort and Spa Hoi An
# 5                            Hoi An Beach Resort
# 6                 Palm Garden Beach Resort & Spa
# 7   ENSO Retreat Hoi An - Rediscovery & Serenity
# 8          Sứ Retreat Hoi An - Riverfront Resort
# 9                           Banla Boutique Hotel
# 10                       Mơ Stay - Forest Resort
# 11         Ana Mandara Villas Dalat Resort & Spa
# 12                                 Colline Dalat
# 13             Terracotta Hotel and Resort Dalat
# 14              Le Recit Boutique Hotel de Dalat
# 15               Swiss-Belresort Tuyen Lam Dalat
# 16                     Nexus House An Son Da Lat
# 17                       The Pink Boutique Hotel
# 18                     Túi Ba Gang Central Hotel
# 19                      Mùa Dalat Wellness Hotel
#
#                                             room_type   price_w1   price_w2  \
# 0                    Standard Double with Garden View  1,958,596  2,312,612
# 1   Superior 2 giường hoặc giường đôi (Superior Tw...  2,032,029  2,048,566
# 2    Deluxe, Guest room, 2 Twin, Garden view, Balcony  2,400,000  2,400,000
# 3       Phòng Đôi Hướng Sông (River View Double Room)  3,043,502  3,027,730
# 4   Bungalow Nhìn ra vườn (Bungalow with Garden View)  2,389,523  1,850,544
# 5                      Phòng Superior (Superior Room)  1,683,957  1,765,432
# 6   Superior giường đôi hoặc 2 giường đơn Hướng vư...  2,380,734  2,380,734
# 7   Phòng Deluxe giường đôi Hướng vườn (Deluxe Dou...  1,432,981  1,432,981
# 8   Suite Lớn có Ban Công (Executive Suite with Ba...  3,218,695  2,423,407
# 9                                 Classic Double Room    919,555  1,125,220
# 10                                Deluxe Balcony Room  3,880,071  2,950,368
# 11                                  Villa Double Room  2,010,582  2,261,905
# 12                               Superior Double Room  1,733,862  1,733,862
# 13                                      Superior Twin  1,784,832  1,784,832
# 14                                        Deluxe Twin    966,490    966,490
# 15                     Deluxe Mountain View King Room  1,089,325  1,089,325
# 16                       Standard Double with Balcony    561,320    613,747
# 17                                     Classic Double    870,098    870,098
# 18                               Deluxe Room -- 1 Bed    768,120  1,102,293
# 19                               Superior Double Room  1,315,870  1,667,549
#
#      price_w3   price_w4   price_w5   price_w6
# 0   2,388,041  1,958,596  1,958,596  2,331,609
# 1   2,118,194  2,255,810  2,099,676  2,200,046
# 2   2,500,000  2,400,000  2,400,000  2,300,000
# 3   3,069,251  2,425,595  2,677,971  2,353,462
# 4   1,853,518  1,851,715  1,853,072  1,851,139
# 5   1,606,349  1,606,349  1,496,296  1,392,593
# 6   2,380,734  2,380,734  3,219,048  2,995,503
# 7   1,432,981  1,432,981  1,432,981  1,432,981
# 8   2,423,407  2,423,407  2,423,407  2,423,407
# 9   1,125,220  1,125,220  1,125,220    919,555
# 10  3,738,977  3,738,977  3,738,977  3,569,024
# 11  2,261,905  2,261,905  2,261,905  2,261,905
# 12  1,733,862  1,733,862  1,703,968  1,703,968
# 13  1,869,489  1,590,000  1,766,667  1,766,667
# 14    966,490    966,490  1,287,478    966,490
# 15  1,111,111  1,111,111  1,089,325  1,244,942
# 16    613,747    600,826    600,826    600,826
# 17  1,065,307  1,065,307  1,065,307  1,065,307
# 18  1,102,293  1,102,293    857,339    857,339
# 19  1,667,549  1,667,549  1,667,549  1,667,549

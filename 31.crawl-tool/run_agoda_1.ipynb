# %% [markdown]
# # 🏨 AGODA Price Crawler
#
# Chạy lần lượt các cell từ trên xuống: **① Cấu hình → ② Đọc input → ③ Crawl → ④ Xem kết quả**.
#
# **Đổi nguồn input:** sửa `INPUT_MODE` ở cell ① — `"gsheet"` (Google Sheet online) hoặc `"offline"` (file CSV/XLSX trên máy).
#
# **Format file offline:** chỉ cần **3 cột đầu theo đúng thứ tự** `hotel_name, hotel_url, room_type` (tên cột không quan trọng, chỉ cần đúng thứ tự). Có file mẫu ở `input/TEMPLATE_hotels.csv`.
#
# **Output** nằm trong `results/agoda/<RUN_NAME>/` — mỗi notebook 1 thư mục riêng (đặt `RUN_NAME` ở cell ①, mỗi notebook 1 tên khác nhau để không ghi đè lẫn nhau):
# - `FINAL_<YYYYMMDD>.csv` — kết quả cuối
# - `TEMP_agoda.csv` — checkpoint: lỡ tắt giữa chừng, chạy lại cell ③ sẽ tự resume phần chưa xong — hotel **chưa từng cào** sẽ chạy trước, hotel còn NA/SOLD OUT retry sau
#
# Cache warm (`results/agoda/captures/`) vẫn dùng chung giữa các notebook nên không tốn thêm thời gian warm.

# %%
# ════════════════ ① CẤU HÌNH ════════════════

# ── Tên run: kết quả nằm RIÊNG trong results/agoda/<RUN_NAME>/ ──
# ⚠️ Mỗi notebook phải đặt 1 tên KHÁC nhau (notebook này "run1", notebook kia "run2")
RUN_NAME = "run1"

# ── Nguồn input: "gsheet" (online) hoặc "offline" (file trên máy) ──
INPUT_MODE = "gsheet"

# Dùng khi INPUT_MODE = "gsheet" (gid của tab được tự lấy từ URL)
GSHEET_URL = "https://docs.google.com/spreadsheets/d/1EauwTNOMVMBT_CUHwf4EtOz1nsZAjG2SJ_LEh199N0Q/edit?gid=1289817800#gid=1289817800"

# Dùng khi INPUT_MODE = "offline" — đường dẫn tuyệt đối, hoặc tương đối so với 31.crawl-tool
# ⚠️ File phải có 3 cột đầu là (tên KS, URL, loại phòng) — file "TEMP_*" là checkpoint OUTPUT, không phải input!
OFFLINE_FILE = "input/v"

# ── Tham số crawl ──
WEEKS      = 6      # số tuần cần crawl
MAX_HOTELS = 0      # 0 = crawl tất cả; đặt 5 để test nhanh 5 khách sạn đầu
SHARD      = ""     # "" = không chia; "1/3" = chạy phần 1 trong 3 phần (chạy lần lượt 1/3, 2/3, 3/3)

# %%
# ════════════════ ② ĐỌC INPUT ════════════════
import os, sys

if "ROOT" not in globals():                    # giữ nguyên ROOT khi chạy lại cell
    ROOT = os.path.abspath("")                 # .../31.crawl-tool (nơi đặt notebook này)
assert os.path.isdir(os.path.join(ROOT, "crawler")), (
    f"Không tìm thấy package `crawler` trong {ROOT} — hãy mở notebook từ thư mục 31.crawl-tool")
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

import crawler
from crawler.hotels_io import read_hotels

if INPUT_MODE == "gsheet":
    INPUT = GSHEET_URL
    print("📡 Input: Google Sheet online")
else:
    INPUT = OFFLINE_FILE if os.path.isabs(OFFLINE_FILE) else os.path.join(ROOT, OFFLINE_FILE)
    assert os.path.exists(INPUT), f"Không tìm thấy file: {INPUT}"
    print(f"📁 Input: file offline — {INPUT}")

hotels = read_hotels(INPUT)
print(f"✅ Đọc được {len(hotels)} khách sạn. 5 dòng đầu:")
for name, url, room in hotels[:5]:
    print(f"   • {name} — {room}")
# Out:
# 📡 Input: Google Sheet online
# ✅ Đọc được 157 khách sạn. 5 dòng đầu:
#    • Almanty - Junior Suite — Junior Suite
#    • Almanty - Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Bể Bơi (Superior Pool Double or Twin) — Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Bể Bơi (Superior Pool Double or Twin)
#    • Almanty - Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Thị Trấn (Superior Town Double or Twin) — Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Thị Trấn (Superior Town Double or Twin)
#    • Almanty - Phòng Đôi hoặc Hai Giường Đơn có Gác Xép (Loft Room Double or Twin) — Phòng Đôi hoặc Hai Giường Đơn có Gác Xép (Loft Room Double or Twin)
#    • Almanty - Phòng Đôi hoặc Hai Giường Đơn Loại Sang Hướng Bể Bơi (Deluxe Pool Double or Twin) — Phòng Đôi hoặc Hai Giường Đơn Loại Sang Hướng Bể Bơi (Deluxe Pool Double or Twin)

# %%
# (TÙY CHỌN) Tải Google Sheet về file offline — lần sau chỉ cần đổi INPUT_MODE = "offline"
import pandas as pd
from crawler.hotels_io import _gsheet_url

os.makedirs(os.path.join(ROOT, "input"), exist_ok=True)
dest = os.path.join(ROOT, "input", "agoda_hotels.csv")
pd.read_csv(_gsheet_url(GSHEET_URL)).to_csv(dest, index=False, encoding="utf-8-sig")
print(f"💾 Đã lưu bản offline: {dest}")
# Out:
# 💾 Đã lưu bản offline: /Users/hchinhtrung/Documents/GitHub/mvillage-email-template/31.crawl-tool/input/agoda_hotels.csv

# %%
# ════════════════ ③ CRAWL ════════════════
OUTDIR = os.path.join(ROOT, "results", "agoda", RUN_NAME)   # mỗi notebook 1 thư mục kết quả riêng
os.makedirs(OUTDIR, exist_ok=True)
os.chdir(OUTDIR)                     # output (FINAL_*.csv, TEMP_agoda.csv) nằm ở đây

kwargs = dict(
    site="agoda",                    # direct replay (nhanh) + Camoufox warm
    input=INPUT,
    weeks=WEEKS,
    # cache warm dùng CHUNG cho mọi notebook (đỡ warm lại) — chỉ kết quả là tách riêng
    capture_dir=os.path.join(ROOT, "results", "agoda", "captures"),
)
if MAX_HOTELS:
    kwargs["max"] = MAX_HOTELS
if SHARD:
    kwargs["shard"] = SHARD

await crawler.arun(**kwargs)         # notebook cho phép await trực tiếp
# Out:
# 📂 Resume: 58 rows from TEMP_agoda.csv
# 🚀 AGODA crawl | 157 hotels × 6w | direct+fallback | engine=camoufox | W1=2026-07-27
# 🦊 Camoufox ready (humanize=True geoip=True) — browser navs use anti-detect Firefox
# ✔️  1/157 Almanty - Junior Suite — complete, skip
# ✔️  2/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Bể Bơi (Superior Pool Double or Twin) — complete, skip
# ✔️  3/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn Cao Cấp Hướng Thị Trấn (Superior Town Double or Twin) — complete, skip
# ✔️  4/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn có Gác Xép (Loft Room Double or Twin) — complete, skip
# ✔️  5/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn Loại Sang Hướng Bể Bơi (Deluxe Pool Double or Twin) — complete, skip
# ✔️  6/157 Almanty - Phòng Đôi hoặc Hai Giường Đơn Loại Sang Hướng Thị Trấn (Deluxe Town Double or Twin) — complete, skip
# ✔️  7/157 Almanty - Suite có Bồn Sục Trên Tầng Thượng (Rooftop Jacuzzi Suite) — complete, skip
# ✔️  8/157 Almanty - Suite Giường Lớn hoặc Hai Giường Đơn Thương Gia (Executive Suite King or Twin) — complete, skip
# ✔️  9/157 Almanty - Suite Tổng thống (Presidental Suite) — complete, skip
# ✔️  10/157 Ana Mandara Villas Dalat Resort & Spa — complete, skip
# ✔️  11/157 Ancient Huế Garden Houses (Ancient Hue Garden Houses) — complete, skip
# ✔️  12/157 Au Lac Charner — complete, skip
# ✔️  13/157 Au Lac Charner — complete, skip
# ✔️  15/157 Bach Place Dalat — complete, skip
# ✔️  16/157 Bakhan Village Resort — complete, skip
# ✔️  17/157 Ban la - Attic Deluxe Room (Attic Deluxe Room) — complete, skip
# ✔️  18/157 Ban la - Deluxe giường đôi có cửa sổ (Deluxe Double with Window) — complete, skip
# ✔️  19/157 Ban la - Phòng cổ điển giường đôi (Classic Double Room) — complete, skip
# ✔️  22/157 Ban la - Phòng Executive giường đôi (Executive Double Room) — complete, skip
# ✔️  24/157 Ban la - Phòng Hai Giường Đơn Loại Sang (Deluxe Twin Room) — complete, skip
# ✔️  25/157 Ban la - Phòng Hạng Sang Giường Đôi (Elite Double Room) — complete, skip
# ✔️  26/157 Ban la - Phòng Loại Sang Giường Đôi Có Ban Công Và Bồn Tắm (Deluxe Double Room with Balcony and Bathtub) — complete, skip
# ✔️  27/157 Ban la - Phòng Suite Hướng núi (Suite Mountain View) — complete, skip
# ✔️  29/157 Ban la - Phòng Thương Hiệu (Signature Room) — complete, skip
# ✔️  30/157 Ban la - Phòng Tiêu Chuẩn Giường Đôi (Standard Double Room) — complete, skip
# ⏭️  Resume order: 99 new hotels first, 33 NA/SOLD-OUT retries after
#
# 🏨 59/157 Grand Hoi An - Villa Suite with Terrace | Villa Suite with Terrace | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=3
#
# 🏨 60/157 Harvest Day Hoi An - Hotel | Standard Double with Garden View | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=4
#
# 🏨 61/157 Hato | Deluxe Double No Window | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=4
#
# 🏨 62/157 Hato | Premium Twin Room - Non-Smoking | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=5
#
# 🏨 63/157 HIIVE by fusion Binh Duong - VSIP 1 | Superior Twin | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [HIIVE by fusion Binh D] W2: 2,126,279 (08/03, Superior Twin)
#       ✅ [HIIVE by fusion Binh D] W1: 2,203,880 (07/27, Superior Twin)
#       ✅ [HIIVE by fusion Binh D] W3: 2,126,279 (08/10, Superior Twin)
#       ✅ [HIIVE by fusion Binh D] W4: 2,126,279 (08/17, Superior Twin)
#       ✅ [HIIVE by fusion Binh D] W6: 2,126,279 (08/31, Superior Twin)
#       ✅ [HIIVE by fusion Binh D] W5: 2,126,279 (08/24, Superior Twin)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=5
#
# 🏨 64/157 Hoi An Beach Resort | Phòng Superior (Superior Room) | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=5
#
# 🏨 65/157 Hotel de la Coupole - MGallery | Classic Room Twin | need weeks [1, 2, 3, 4, 5, 6]
#    ⚠️ 0/6 priced (direct 0, fallback 0) | pace limit=8
#
# 🏨 66/157 KK Sapa Hotel | Superior Twin City View | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 67/157 KOI Resort and Spa Hoi An | Bungalow Nhìn ra vườn (Bungalow with Garden View) | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 68/157 La siesta - Khu Club 2 tầng Suite có ban công (Club Wing Duplex Suite with Balcony) | Khu Club 2 tầng Suite có ban công (Club Wing Duplex Suite with Balcony) | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 69/157 La siesta - Khu Club cao cấp Suite có ban công (Club Wing Premium Suite with Terrace) | Khu Club cao cấp Suite có ban công (Club Wing Premium Suite with Terrace) | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=1
#
# 🏨 70/157 La siesta - Khu Club hướng hồ bơi Varanda Suite (Club Wing Pool View Veranda Suite) | Khu Club hướng hồ bơi Varanda Suite (Club Wing Pool View Veranda Suite) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=1
#
# 🏨 71/157 La siesta - Khu Club Junior Suite có ban công (Club Wing Junior Suite with Balcony) | Khu Club Junior Suite có ban công (Club Wing Junior Suite with Balcony) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=2
#
# 🏨 72/157 La siesta - Khu Cổ điển Grand Suite (Classic Wing Grand Suite) | Khu Cổ điển Grand Suite (Classic Wing Grand Suite) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=3
#
# 🏨 73/157 La siesta - Khu Cổ điển Phòng Deluxe (Classic Wing Deluxe Room) | Khu Cổ điển Phòng Deluxe (Classic Wing Deluxe Room) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=3
#
# 🏨 74/157 La siesta - Khu Cổ điển Phòng Gia đình (Classic Wing Family Room) | Khu Cổ điển Phòng Gia đình (Classic Wing Family Room) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=4
#
# 🏨 75/157 La siesta - La Siesta Suite | La Siesta Suite | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=5
#
# 🏨 76/157 La siesta - Phòng Đôi Loại Sang Phía Cổ Điển có Ban Công (Classic Wing Deluxe Double Room with Balcony) | Phòng Đôi Loại Sang Phía Cổ Điển có Ban Công (Classic Wing Deluxe Double Room with Balcony) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=5
#
# 🏨 77/157 La siesta - Phòng Hai Giường Đơn Loại Sang Phía Cổ Điển có Ban Công (Classic Wing Deluxe Twin Room with Balcony) | Phòng Hai Giường Đơn Loại Sang Phía Cổ Điển có Ban Công (Classic Wing Deluxe Twin Room with Balcony) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=6
#
# 🏨 78/157 La siesta - Suite | Suite | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=6
#
# 🏨 79/157 La siesta - Suite Hai Tầng Thương Gia Phía Hội Viên có Ban Công (Club Wing Executive Duplex Suite with Balcony) | Suite Hai Tầng Thương Gia Phía Hội Viên có Ban Công (Club Wing Executive Duplex Suite with Balcony) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=7
#
# 🏨 80/157 La siesta - Suite La Siesta - Cánh Cổ Điển (La Siesta Suite - Classic Wing) | Suite La Siesta - Cánh Cổ Điển (La Siesta Suite - Classic Wing) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 81/157 La siesta - Suite Lớn Phía Hội Viên Hướng Bể Bơi (Club Wing Executive Pool View Suite) | Suite Lớn Phía Hội Viên Hướng Bể Bơi (Club Wing Executive Pool View Suite) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 82/157 La Siesta Hoi An Resort & Spa | Club Wing Junior Suite with Balcony | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 83/157 La Siesta Hoi An Resort & Spa 1 | Classic Wing Deluxe Room | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 84/157 Le Récit - Deluxe giường đôi (Deluxe Double) | Deluxe giường đôi (Deluxe Double) | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 85/157 Le Récit - Penthouse | Penthouse | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 86/157 Le Récit - Phòng Deluxe 2 Giường đơn (Deluxe Twin) | Phòng Deluxe 2 Giường đơn (Deluxe Twin) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 87/157 Le Récit - Suite Căn Hộ Áp Mái 1 Phòng Ngủ (Penthouse 1 Bedroom Suite) | Suite Căn Hộ Áp Mái 1 Phòng Ngủ (Penthouse 1 Bedroom Suite) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 88/157 Le Récit - Suite dạng Căn hộ áp mái 2 Phòng ngủ (Penthouse 2 Bedroom Suite) | Suite dạng Căn hộ áp mái 2 Phòng ngủ (Penthouse 2 Bedroom Suite) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 89/157 Le Récit - Suite Deluxe (Deluxe Suite) | Suite Deluxe (Deluxe Suite) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 90/157 Le Récit - Suite Giường Lớn (King Suite) | Suite Giường Lớn (King Suite) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 91/157 Le Recit Boutique Hotel de Dalat | Deluxe Twin | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 92/157 Legacy Mekong | Bungalow, 2 Twin, Garden View | need weeks [1, 2, 3, 4, 5, 6]
#    ⚠️ 0/6 priced (direct 0, fallback 0) | pace limit=8
#
# 🏨 93/157 M Hotel | Zen Corner | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=8
#
# 🏨 94/157 Mai Chau Ecolodge | Superior Twin Room with Garden View | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [Mai Chau Ecolodge] W6 08/31: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Mai Chau Ecolodge] W6 09/01: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⛔ [Mai Chau Ecolodge] W6 09/01: blocked 2× in a row → skip rest of hotel (fast NA; cooldown rounds retry later)
#       ❌ [Mai Chau Ecolodge] W6: NA
#    ⚠️ 0/6 priced (direct 0, fallback 1) | pace limit=4
#
# 🏨 95/157 Mit Retreat | One Bedroom Deluxe Mountain View | need weeks [1, 2, 3, 4, 5, 6]
#    ⚠️ 5/6 priced (direct 5, fallback 0) | pace limit=1
#
# 🏨 96/157 Mơ Stay - Forest Resort | Deluxe Balcony Room | need weeks [1, 2, 3, 4, 5, 6]
#    ✅ 6/6 priced (direct 6, fallback 0) | pace limit=2
#
# 🏨 97/157 Moire Hội An -1 King Premium River View | 1 King Premium River View | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [Moire Hội An -1 Ki] W3 08/10: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W1 08/01: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W3 08/15: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W1 08/02: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W3 08/16: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       🚫 [Moire Hội An -1 King P] W1: SOLD OUT
#       🚫 [Moire Hội An -1 King P] W3: SOLD OUT
#       ⟳ [Moire Hội An -1 Ki] W6 08/31: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W6 09/01: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W6 09/02: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W6 09/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W6 09/04: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W6 09/05: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W6 09/06: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ❌ [Moire Hội An -1 King P] W6: NA
#    ⚠️ 0/6 priced (direct 0, fallback 3) | pace limit=1
#
# 🏨 98/157 Moire Hội An -1 King Premium Terrace Access | 1 King Premium Terrace Access | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [Moire Hội An -1 Ki] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W1 07/31: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W2 08/07: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W2 08/08: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W1 08/02: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       🚫 [Moire Hội An -1 King P] W1: SOLD OUT
#       ⟳ [Moire Hội An -1 Ki] W2 08/09: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -1 Ki] W3 08/10: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       🚫 [Moire Hội An -1 King P] W2: SOLD OUT
#       ⟳ [Moire Hội An -1 Ki] W3 08/11: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       🚫 [Moire Hội An -1 King P] W3: SOLD OUT
#    ⚠️ 0/6 priced (direct 0, fallback 3) | pace limit=3
#
# 🏨 99/157 Moire Hội An -1 King Suite River View | 1 King Suite River View | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ⚠️ 0/6 priced (direct 0, fallback 0) | pace limit=7
#
# 🏨 100/157 Moire Hội An -2 Twin Deluxe River View | 2 Twin Deluxe River View | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ⚠️ 0/6 priced (direct 0, fallback 0) | pace limit=8
#
# 🏨 101/157 Moire Hội An -Moire Pool Villa | Moire Pool Villa | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️→🔥 cached capture stale — warming fresh
#       ⟳ [Moire Hội An -Moir] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -Moir] W3 08/10: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⛔ [Moire Hội An -Moir] W3 08/10: blocked 2× in a row → skip rest of hotel (fast NA; cooldown rounds retry later)
#       ❌ [Moire Hội An -Moire Po] W2: NA
#       ❌ [Moire Hội An -Moire Po] W4: NA
#       ❌ [Moire Hội An -Moire Po] W5: NA
#       ❌ [Moire Hội An -Moire Po] W6: NA
#       ❌ [Moire Hội An -Moire Po] W3: NA
#    ⚠️ 0/6 priced (direct 0, fallback 5) | pace limit=1
#
# 🏨 102/157 Moire Hội An -Phòng Deluxe có 2 giường đơn (2 Twin Deluxe) | Phòng Deluxe có 2 giường đơn (2 Twin Deluxe) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️→🔥 cached capture stale — warming fresh
#    ⚠️ 0/6 priced (direct 0, fallback 0) | pace limit=4
#
# 🏨 103/157 Moire Hội An -Phòng Deluxe có giường King - Phù hợp cho người khuyết tật (1 King Deluxe Accessible) | Phòng Deluxe có giường King - Phù hợp cho người khuyết tật (1 King Deluxe Accessible) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#    ⚠️ 0/6 priced (direct 0, fallback 0) | pace limit=8
#
# 🏨 104/157 Moire Hội An -Phòng Deluxe có giường King (1 King Deluxe) | Phòng Deluxe có giường King (1 King Deluxe) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️ cached capture alive — warm skipped
#       ⟳ [Moire Hội An -Phòn] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -Phòn] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⛔ [Moire Hội An -Phòn] W2 08/03: blocked 2× in a row → skip rest of hotel (fast NA; cooldown rounds retry later)
#       ❌ [Moire Hội An -Phòng De] W1: NA
#       ❌ [Moire Hội An -Phòng De] W4: NA
#       ❌ [Moire Hội An -Phòng De] W6: NA
#       ❌ [Moire Hội An -Phòng De] W2: NA
#    ⚠️ 0/6 priced (direct 0, fallback 4) | pace limit=1
#
# 🏨 105/157 Moire Hội An -Phòng Loại Sang (Deluxe Room) | Phòng Loại Sang (Deluxe Room) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️→🔥 cached capture stale — warming fresh
#       ⟳ [Moire Hội An -Phòn] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -Phòn] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⛔ [Moire Hội An -Phòn] W2 08/03: blocked 2× in a row → skip rest of hotel (fast NA; cooldown rounds retry later)
#       ❌ [Moire Hội An -Phòng Lo] W2: NA
#       ❌ [Moire Hội An -Phòng Lo] W3: NA
#       ❌ [Moire Hội An -Phòng Lo] W4: NA
#       ❌ [Moire Hội An -Phòng Lo] W5: NA
#       ❌ [Moire Hội An -Phòng Lo] W6: NA
#       ❌ [Moire Hội An -Phòng Lo] W1: NA
#    ⚠️ 0/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 106/157 Moire Hội An -Phòng Loại Sang 1 Giường Lớn Hướng Sông (1 King Deluxe River View) | Phòng Loại Sang 1 Giường Lớn Hướng Sông (1 King Deluxe River View) | need weeks [1, 2, 3, 4, 5, 6]
#    ♻️→🔥 cached capture stale — warming fresh
#       ⟳ [Moire Hội An -Phòn] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hội An -Phòn] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⛔ [Moire Hội An -Phòn] W1 07/27: blocked 2× in a row → skip rest of hotel (fast NA; cooldown rounds retry later)
#       ❌ [Moire Hội An -Phòng Lo] W2: NA
#       ❌ [Moire Hội An -Phòng Lo] W3: NA
#       ❌ [Moire Hội An -Phòng Lo] W4: NA
#       ❌ [Moire Hội An -Phòng Lo] W5: NA
#       ❌ [Moire Hội An -Phòng Lo] W6: NA
#       ❌ [Moire Hội An -Phòng Lo] W1: NA
#    ⚠️ 0/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 107/157 Moire Hoi An Vignette Collection By IHG | 1 King Deluxe | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [Moire Hoi An Vigne] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Moire Hoi An Vigne] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⛔ [Moire Hoi An Vigne] W2 08/03: blocked 2× in a row → skip rest of hotel (fast NA; cooldown rounds retry later)
#       ❌ [Moire Hoi An Vignette ] W2: NA
#       ❌ [Moire Hoi An Vignette ] W3: NA
#       ❌ [Moire Hoi An Vignette ] W4: NA
#       ❌ [Moire Hoi An Vignette ] W5: NA
#       ❌ [Moire Hoi An Vignette ] W6: NA
#       ⟳ [Moire Hoi An Vigne] W1 07/28: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ❌ [Moire Hoi An Vignette ] W1: NA
#    🔻 direct replay dead for 3 hotels in a row — switching to browser-only for the rest of the run
#    ⚠️ 0/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 108/157 Mùa Dalat Wellness Hotel | Superior Double Room | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [Mùa Dalat Wellness] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Mùa Dalat Wellness] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [Mùa Dalat Wellness Hot] W2: 1,667,549 (08/03, Superior Double Room)
#       ✅ [Mùa Dalat Wellness Hot] W1: 1,667,549 (07/27, Superior Double Room)
#       ✅ [Mùa Dalat Wellness Hot] W3: 1,667,549 (08/10, Superior Double Room)
#       ✅ [Mùa Dalat Wellness Hot] W4: 1,667,549 (08/17, Superior Double Room)
#       ✅ [Mùa Dalat Wellness Hot] W5: 1,667,549 (08/24, Superior Double Room)
#       ✅ [Mùa Dalat Wellness Hot] W6: 1,667,549 (08/31, Superior Double Room)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 109/157 MV Hotel Hoi An - Deluxe giường King có ban công (Deluxe King with Balcony) | Deluxe giường King có ban công (Deluxe King with Balcony) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [MV Hotel Hoi An - Delu] W1: 1,877,778 (07/27, Deluxe giường King c)
#       ✅ [MV Hotel Hoi An - Delu] W2: 2,262,963 (08/03, Deluxe giường King c)
#       ✅ [MV Hotel Hoi An - Delu] W3: 2,262,963 (08/10, Deluxe giường King c)
#       ✅ [MV Hotel Hoi An - Delu] W4: 2,246,914 (08/17, Deluxe giường King c)
#       ✅ [MV Hotel Hoi An - Delu] W5: 2,155,203 (08/24, Deluxe giường King c)
#       ✅ [MV Hotel Hoi An - Delu] W6: 2,613,757 (08/31, Deluxe giường King c)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 110/157 MV Hotel Hoi An - Deluxe King Pool View with Balcony | Deluxe King Pool View with Balcony | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [MV Hotel Hoi An - Delu] W1: 2,303,704 (07/27, Deluxe King Pool Vie)
#       ✅ [MV Hotel Hoi An - Delu] W2: 2,400,000 (08/03, Deluxe King Pool Vie)
#       ⟳ [MV Hotel Hoi An - ] W3 08/10: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [MV Hotel Hoi An - ] W4 08/17: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [MV Hotel Hoi An - Delu] W4: 2,560,847 (08/17, Deluxe King Pool Vie)
#       ✅ [MV Hotel Hoi An - Delu] W3: 2,400,000 (08/10, Deluxe King Pool Vie)
#       ✅ [MV Hotel Hoi An - Delu] W6: 1,986,404 (08/31, Deluxe King Pool Vie)
#       ✅ [MV Hotel Hoi An - Delu] W5: 2,285,714 (08/24, Deluxe King Pool Vie)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 111/157 MV Hotel Hoi An - Duplex City View with Balcony | Duplex City View with Balcony | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [MV Hotel Hoi An - Dupl] W1: 2,811,111 (07/27, Duplex City View wit)
#       ✅ [MV Hotel Hoi An - Dupl] W2: 3,100,000 (08/03, Duplex City View wit)
#       ✅ [MV Hotel Hoi An - Dupl] W3: 3,100,000 (08/10, Duplex City View wit)
#       ✅ [MV Hotel Hoi An - Dupl] W4: 2,952,381 (08/17, Duplex City View wit)
#       ✅ [MV Hotel Hoi An - Dupl] W5: 2,952,381 (08/24, Duplex City View wit)
#       ✅ [MV Hotel Hoi An - Dupl] W6: 3,410,935 (08/31, Duplex City View wit)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 112/157 MV Hotel Hoi An - Grand Suite 1 Bedroom | Grand Suite 1 Bedroom | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [MV Hotel Hoi An - Gran] W1: 3,907,407 (07/27, Grand Suite 1 Bedroo)
#       ✅ [MV Hotel Hoi An - Gran] W2: 4,196,296 (08/03, Grand Suite 1 Bedroo)
#       ✅ [MV Hotel Hoi An - Gran] W3: 4,196,296 (08/10, Grand Suite 1 Bedroo)
#       ✅ [MV Hotel Hoi An - Gran] W4: 3,996,473 (08/17, Grand Suite 1 Bedroo)
#       ✅ [MV Hotel Hoi An - Gran] W5: 3,904,762 (08/24, Grand Suite 1 Bedroo)
#       ✅ [MV Hotel Hoi An - Gran] W6: 4,363,316 (08/31, Grand Suite 1 Bedroo)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 113/157 MV Hotel Hoi An - Phòng Deluxe 2 Giường đơn với Ban công (Deluxe Twin Beds with Balcony) | Phòng Deluxe 2 Giường đơn với Ban công (Deluxe Twin Beds with Balcony) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [MV Hotel Hoi An - Phòn] W2: 2,200,000 (08/03, Phòng Deluxe 2 Giườn)
#       ✅ [MV Hotel Hoi An - Phòn] W1: 1,814,815 (07/27, Phòng Deluxe 2 Giườn)
#       ✅ [MV Hotel Hoi An - Phòn] W3: 2,262,963 (08/10, Phòng Deluxe 2 Giườn)
#       ✅ [MV Hotel Hoi An - Phòn] W4: 2,095,238 (08/17, Phòng Deluxe 2 Giườn)
#       ✅ [MV Hotel Hoi An - Phòn] W5: 2,095,238 (08/24, Phòng Deluxe 2 Giườn)
#       ✅ [MV Hotel Hoi An - Phòn] W6: 2,553,792 (08/31, Phòng Deluxe 2 Giườn)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 114/157 MV Hotel Hoi An - Phòng Loại Sang Hướng Bể Bơi 2 Giường Đơn (Deluxe Twin Pool View) | Phòng Loại Sang Hướng Bể Bơi 2 Giường Đơn (Deluxe Twin Pool View) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [MV Hotel Hoi An - Phòn] W1: 1,914,815 (07/27, Phòng Loại Sang Hướn)
#       ✅ [MV Hotel Hoi An - Phòn] W2: 2,300,000 (08/03, Phòng Loại Sang Hướn)
#       ✅ [MV Hotel Hoi An - Phòn] W3: 2,300,000 (08/10, Phòng Loại Sang Hướn)
#       ✅ [MV Hotel Hoi An - Phòn] W4: 2,282,187 (08/17, Phòng Loại Sang Hướn)
#       ✅ [MV Hotel Hoi An - Phòn] W5: 2,190,476 (08/24, Phòng Loại Sang Hướn)
#       ✅ [MV Hotel Hoi An - Phòn] W6: 2,649,030 (08/31, Phòng Loại Sang Hướn)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 115/157 Nexus House An Son Da Lat | Standard Double with Balcony | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Nexus House An Son Da ] W1: 620,346 (07/27, Standard Double with)
#       ✅ [Nexus House An Son Da ] W2: 620,346 (08/03, Standard Double with)
#       ✅ [Nexus House An Son Da ] W4: 607,286 (08/17, Standard Double with)
#       ✅ [Nexus House An Son Da ] W3: 620,346 (08/10, Standard Double with)
#       ✅ [Nexus House An Son Da ] W6: 607,286 (08/31, Standard Double with)
#       ✅ [Nexus House An Son Da ] W5: 607,286 (08/24, Standard Double with)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 116/157 Palm Garden Beach Resort & Spa | Superior giường đôi hoặc 2 giường đơn Hướng vườn (Superior Double or Twin with Garden View) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Palm Garden Beach Reso] W2: 2,403,070 (08/03, Superior giường đôi )
#       ✅ [Palm Garden Beach Reso] W3: 2,403,070 (08/10, Superior giường đôi )
#       ✅ [Palm Garden Beach Reso] W4: 2,403,070 (08/17, Superior giường đôi )
#       ✅ [Palm Garden Beach Reso] W5: 2,403,070 (08/24, Superior giường đôi )
#       ✅ [Palm Garden Beach Reso] W6: 2,995,503 (08/31, Superior giường đôi )
#       ✅ [Palm Garden Beach Reso] W1: 2,403,070 (07/31, Superior giường đôi )
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 117/157 Pao's Sapa Leisure Hotel | Deluxe Garden View | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Pao's Sapa Leisure Hot] W1: 1,944,444 (07/27, Deluxe Garden View)
#       ✅ [Pao's Sapa Leisure Hot] W2: 1,944,444 (08/03, Deluxe Garden View)
#       ✅ [Pao's Sapa Leisure Hot] W3: 1,944,444 (08/10, Deluxe Garden View)
#       ✅ [Pao's Sapa Leisure Hot] W4: 1,944,444 (08/17, Deluxe Garden View)
#       ✅ [Pao's Sapa Leisure Hot] W5: 1,944,444 (08/24, Deluxe Garden View)
#       ✅ [Pao's Sapa Leisure Hot] W6: 1,915,132 (08/31, Deluxe Garden View)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 118/157 Renaissance Danang Hoi An Resort & Spa | Deluxe, Guest room, 2 Twin, Garden view, Balcony | need weeks [1, 2, 3, 4, 5, 6]
#       🚫 [Renaissance Danang Hoi] W2: SOLD OUT
#       🚫 [Renaissance Danang Hoi] W1: SOLD OUT
#       🚫 [Renaissance Danang Hoi] W3: SOLD OUT
#       🚫 [Renaissance Danang Hoi] W4: SOLD OUT
#       🚫 [Renaissance Danang Hoi] W5: SOLD OUT
#       🚫 [Renaissance Danang Hoi] W6: SOLD OUT
#    ⚠️ 0/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 119/157 Reu Boutique Hotel - Hotel | Superior 2 giường hoặc giường đôi (Superior Twin or Double) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Reu Boutique Hotel - H] W1: 2,425,044 (07/27, Superior 2 giường ho)
#       ✅ [Reu Boutique Hotel - H] W2: 2,425,044 (08/03, Superior 2 giường ho)
#       ✅ [Reu Boutique Hotel - H] W4: 2,425,044 (08/17, Superior 2 giường ho)
#       ✅ [Reu Boutique Hotel - H] W3: 2,425,044 (08/10, Superior 2 giường ho)
#       ✅ [Reu Boutique Hotel - H] W5: 2,425,044 (08/24, Superior 2 giường ho)
#       ✅ [Reu Boutique Hotel - H] W6: 2,425,044 (08/31, Superior 2 giường ho)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 120/157 Sapa Jade Hill Resort & Spa | Deluxe Valley View Room | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Sapa Jade Hill Resort ] W1: 1,626,316 (07/27, Deluxe Valley View R)
#       ✅ [Sapa Jade Hill Resort ] W2: 1,862,646 (08/03, Deluxe Valley View R)
#       ✅ [Sapa Jade Hill Resort ] W4: 1,826,825 (08/17, Deluxe Valley View R)
#       ✅ [Sapa Jade Hill Resort ] W3: 1,626,316 (08/10, Deluxe Valley View R)
#       ✅ [Sapa Jade Hill Resort ] W5: 1,826,825 (08/24, Deluxe Valley View R)
#       ✅ [Sapa Jade Hill Resort ] W6: 1,626,316 (09/01, Deluxe Valley View R)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 121/157 Sheraton Can Tho | Guest room, 2 Twin | need weeks [1, 2, 3, 4, 5, 6]
#       🚫 [Sheraton Can Tho] W2: SOLD OUT
#       🚫 [Sheraton Can Tho] W1: SOLD OUT
#       ⟳ [Sheraton Can Tho] W3 08/13: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Sheraton Can Tho] W4 08/20: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       🚫 [Sheraton Can Tho] W3: SOLD OUT
#       🚫 [Sheraton Can Tho] W4: SOLD OUT
#       🚫 [Sheraton Can Tho] W5: SOLD OUT
#       🚫 [Sheraton Can Tho] W6: SOLD OUT
#    ⚠️ 0/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 122/157 Silk Path Grand Sapa Resort & Spa | Classic Garden View | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Silk Path Grand Sapa R] W1: 2,131,746 (07/27, Balcony Classic Gard)
#       ✅ [Silk Path Grand Sapa R] W2: 2,042,982 (08/03, Balcony Classic Gard)
#       ⟳ [Silk Path Grand Sa] W3 08/10: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Silk Path Grand Sa] W4 08/17: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [Silk Path Grand Sapa R] W3: 2,173,545 (08/10, Balcony Classic Gard)
#       ✅ [Silk Path Grand Sapa R] W4: 2,081,834 (08/17, Balcony Classic Gard)
#       ✅ [Silk Path Grand Sapa R] W5: 2,001,764 (08/24, Balcony Classic Gard)
#       ✅ [Silk Path Grand Sapa R] W6: 6,446,208 (08/31, Balcony Classic Gard)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 123/157 Silverland Ben Thanh_Spring Field - No Window | Spring Field - No Window | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Silverland Ben Thanh_S] W2: 2,818,166 (08/03, Spring Field - No Wi)
#       ✅ [Silverland Ben Thanh_S] W3: 3,619,753 (08/10, Spring Field - No Wi)
#       ✅ [Silverland Ben Thanh_S] W4: 3,244,444 (08/17, Spring Field - No Wi)
#       ✅ [Silverland Ben Thanh_S] W1: 2,963,933 (07/28, Spring Field - No Wi)
#       ✅ [Silverland Ben Thanh_S] W5: 3,200,000 (08/24, Spring Field - No Wi)
#       ✅ [Silverland Ben Thanh_S] W6: 3,056,790 (08/31, Spring Field - No Wi)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 124/157 Silverland Ben Thanh_Sunshine Garden - Double or Twin | Sunshine Garden - Double or Twin | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Silverland Ben Thanh_S] W2: 3,503,527 (08/03, Sunshine Garden - Do)
#       ✅ [Silverland Ben Thanh_S] W3: 3,692,769 (08/10, Sunshine Garden - Do)
#       ✅ [Silverland Ben Thanh_S] W4: 3,304,056 (08/17, Sunshine Garden - Do)
#       ✅ [Silverland Ben Thanh_S] W5: 3,258,025 (08/24, Sunshine Garden - Do)
#       ✅ [Silverland Ben Thanh_S] W1: 3,684,744 (07/28, Sunshine Garden - Do)
#       ✅ [Silverland Ben Thanh_S] W6: 3,109,700 (08/31, Sunshine Garden - Do)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 125/157 Sol An Bang Beach Resort & Spa | Deluxe Room | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Sol An Bang Beach Reso] W1: 2,339,046 (07/27, Deluxe Room)
#       ✅ [Sol An Bang Beach Reso] W2: 2,339,046 (08/03, Deluxe Room)
#       ✅ [Sol An Bang Beach Reso] W3: 2,046,665 (08/10, Deluxe Room)
#       ✅ [Sol An Bang Beach Reso] W4: 2,046,665 (08/17, Deluxe Room)
#       ✅ [Sol An Bang Beach Reso] W5: 2,339,046 (08/24, Deluxe Room)
#       ✅ [Sol An Bang Beach Reso] W6: 2,339,046 (08/31, Deluxe Room)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 126/157 Sứ Retreat Hoi An - Riverfront Resort | Suite Lớn có Ban Công (Executive Suite with Balcony) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Sứ Retreat Hoi An - Ri] W1: 2,428,509 (07/27, Suite Lớn có Ban Côn)
#       ✅ [Sứ Retreat Hoi An - Ri] W3: 3,968,254 (08/10, Suite Lớn có Ban Côn)
#       ✅ [Sứ Retreat Hoi An - Ri] W4: 2,428,509 (08/19, Suite Lớn có Ban Côn)
#       ✅ [Sứ Retreat Hoi An - Ri] W5: 2,428,509 (08/24, Suite Lớn có Ban Côn)
#       ✅ [Sứ Retreat Hoi An - Ri] W6: 3,968,254 (08/31, Suite Lớn có Ban Côn)
#       🚫 [Sứ Retreat Hoi An - Ri] W2: SOLD OUT
#    ⚠️ 5/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 127/157 Swiss-Belresort Tuyen Lam Dalat | Deluxe Mountain View King Room | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Swiss-Belresort Tuyen ] W1: 1,094,298 (07/27, Deluxe Mountain View)
#       ✅ [Swiss-Belresort Tuyen ] W2: 1,185,185 (08/03, Deluxe Mountain View)
#       ⟳ [Swiss-Belresort Tu] W3 08/10: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Swiss-Belresort Tu] W4 08/17: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [Swiss-Belresort Tuyen ] W4: 1,089,325 (08/17, Deluxe Mountain View)
#       ✅ [Swiss-Belresort Tuyen ] W3: 1,111,111 (08/10, Deluxe Mountain View)
#       ⟳ [Swiss-Belresort Tu] W5 08/24: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Swiss-Belresort Tu] W6 08/31: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [Swiss-Belresort Tuyen ] W6: 1,387,302 (08/31, Deluxe Mountain View)
#       ✅ [Swiss-Belresort Tuyen ] W5: 1,244,942 (08/24, Deluxe Mountain View)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 128/157 Terracotta Hotel and Resort Dalat | Superior Twin | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Terracotta Hotel and R] W1: 1,784,832 (07/27, Superior Twin)
#       ✅ [Terracotta Hotel and R] W2: 1,843,034 (08/03, Superior Twin)
#       ✅ [Terracotta Hotel and R] W4: 1,766,667 (08/17, Superior Twin)
#       ✅ [Terracotta Hotel and R] W3: 1,766,667 (08/10, Superior Twin)
#       ⟳ [Terracotta Hotel a] W5 08/24: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Terracotta Hotel a] W6 08/31: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [Terracotta Hotel and R] W6: 2,917,284 (08/31, Superior Twin)
#       ✅ [Terracotta Hotel and R] W5: 1,766,667 (08/24, Superior Twin)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 129/157 The Mist Boutique - Deluxe City View | Deluxe City View | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [The Mist Boutique ] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [The Mist Boutique ] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [The Mist Boutique - De] W2: 1,167,763 (08/03, Deluxe City View)
#       ✅ [The Mist Boutique - De] W1: 1,457,143 (07/27, Deluxe City View)
#       ✅ [The Mist Boutique - De] W3: 1,457,143 (08/10, Deluxe City View)
#       ✅ [The Mist Boutique - De] W4: 1,457,143 (08/17, Deluxe City View)
#       ✅ [The Mist Boutique - De] W5: 1,457,143 (08/24, Deluxe City View)
#       ✅ [The Mist Boutique - De] W6: 1,167,763 (08/31, Deluxe City View)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 130/157 The Mist Boutique - Deluxe Mountain View | Deluxe Mountain View | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [The Mist Boutique - De] W2: 1,952,381 (08/03, Deluxe Mountain View)
#       ✅ [The Mist Boutique - De] W1: 1,952,381 (07/27, Deluxe Mountain View)
#       ✅ [The Mist Boutique - De] W3: 1,952,381 (08/10, Deluxe Mountain View)
#       ✅ [The Mist Boutique - De] W4: 1,952,381 (08/17, Deluxe Mountain View)
#       ✅ [The Mist Boutique - De] W5: 1,952,381 (08/24, Deluxe Mountain View)
#       ✅ [The Mist Boutique - De] W6: 1,952,381 (08/31, Deluxe Mountain View)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 131/157 The Mist Boutique - Double Room | Double Room | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [The Mist Boutique - Do] W1: 907,895 (07/27, Double Room)
#       ✅ [The Mist Boutique - Do] W2: 907,895 (08/03, Double Room)
#       ✅ [The Mist Boutique - Do] W4: 907,895 (08/17, Double Room)
#       ✅ [The Mist Boutique - Do] W3: 907,895 (08/10, Double Room)
#       ✅ [The Mist Boutique - Do] W5: 1,133,333 (08/24, Double Room)
#       ✅ [The Mist Boutique - Do] W6: 907,895 (08/31, Double Room)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 132/157 The Mist Boutique - Executive Suite | Executive Suite | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [The Mist Boutique - Ex] W2: 2,223,026 (08/03, Executive Suite)
#       ✅ [The Mist Boutique - Ex] W1: 2,223,026 (07/27, Executive Suite)
#       ✅ [The Mist Boutique - Ex] W4: 2,223,026 (08/17, Executive Suite)
#       ✅ [The Mist Boutique - Ex] W3: 2,438,095 (08/10, Executive Suite)
#       ⟳ [The Mist Boutique ] W5 08/24: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [The Mist Boutique ] W6 08/31: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [The Mist Boutique - Ex] W5: 2,438,095 (08/24, Executive Suite)
#       ✅ [The Mist Boutique - Ex] W6: 2,438,095 (08/31, Executive Suite)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 133/157 The Mist Boutique - Signature Suite | Signature Suite | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [The Mist Boutique - Si] W2: 2,780,953 (08/03, Signature Suite)
#       ✅ [The Mist Boutique - Si] W3: 2,780,953 (08/10, Signature Suite)
#       ✅ [The Mist Boutique - Si] W4: 2,780,953 (08/17, Signature Suite)
#       ✅ [The Mist Boutique - Si] W1: 2,780,953 (07/29, Signature Suite)
#       ✅ [The Mist Boutique - Si] W6: 2,780,953 (08/31, Signature Suite)
#       ✅ [The Mist Boutique - Si] W5: 2,780,953 (08/24, Signature Suite)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 134/157 The Mist Boutique - Suite City View Room | Suite City View Room | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [The Mist Boutique - Su] W1: 1,357,675 (07/27, Suite City View Room)
#       ✅ [The Mist Boutique - Su] W2: 1,357,675 (08/03, Suite City View Room)
#       ✅ [The Mist Boutique - Su] W3: 1,780,952 (08/10, Suite City View Room)
#       ✅ [The Mist Boutique - Su] W4: 1,780,952 (08/17, Suite City View Room)
#       ✅ [The Mist Boutique - Su] W5: 1,780,952 (08/24, Suite City View Room)
#       ✅ [The Mist Boutique - Su] W6: 1,780,952 (08/31, Suite City View Room)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 135/157 The Mist Boutique - Suite Mountain View | Suite Mountain View | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [The Mist Boutique - Su] W2: 2,352,381 (08/03, Suite Mountain View)
#       ✅ [The Mist Boutique - Su] W1: 2,017,982 (07/27, Suite Mountain View)
#       ✅ [The Mist Boutique - Su] W3: 2,352,381 (08/10, Suite Mountain View)
#       ✅ [The Mist Boutique - Su] W4: 2,352,381 (08/17, Suite Mountain View)
#       ✅ [The Mist Boutique - Su] W5: 2,352,381 (08/24, Suite Mountain View)
#       ✅ [The Mist Boutique - Su] W6: 2,352,381 (08/31, Suite Mountain View)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 136/157 The Mist Boutique - Tripple Balcony | Triple Balcony | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [The Mist Boutique - Tr] W1: 1,847,619 (07/28, Triple Deluxe)
#       ✅ [The Mist Boutique - Tr] W2: 1,990,476 (08/04, Triple Balcony)
#       ✅ [The Mist Boutique - Tr] W3: 1,581,579 (08/10, Triple Balcony)
#       ✅ [The Mist Boutique - Tr] W4: 1,990,476 (08/17, Triple Balcony)
#       ✅ [The Mist Boutique - Tr] W5: 1,990,476 (08/24, Triple Balcony)
#       ✅ [The Mist Boutique - Tr] W6: 1,581,579 (08/31, Triple Balcony)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 137/157 The Mist Boutique - Tripple Deluxe | Triple Deluxe | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [The Mist Boutique - Tr] W2: 1,525,219 (08/04, Triple Deluxe)
#       ✅ [The Mist Boutique - Tr] W1: 1,847,619 (07/28, Triple Deluxe)
#       ✅ [The Mist Boutique - Tr] W3: 1,847,619 (08/10, Triple Deluxe)
#       ✅ [The Mist Boutique - Tr] W4: 1,847,619 (08/17, Triple Deluxe)
#       ✅ [The Mist Boutique - Tr] W5: 1,847,619 (08/24, Triple Deluxe)
#       ✅ [The Mist Boutique - Tr] W6: 1,525,219 (08/31, Triple Deluxe)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 138/157 The Pink Boutique Hotel | Classic Double | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [The Pink Boutique ] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [The Pink Boutique ] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [The Pink Boutique Hote] W1: 874,561 (07/27, Classic Double)
#       ✅ [The Pink Boutique Hote] W2: 874,561 (08/03, Classic Double)
#       ✅ [The Pink Boutique Hote] W3: 874,561 (08/10, Classic Double)
#       ✅ [The Pink Boutique Hote] W4: 1,065,307 (08/17, Classic Double)
#       ✅ [The Pink Boutique Hote] W5: 1,065,307 (08/24, Classic Double)
#       ✅ [The Pink Boutique Hote] W6: 874,561 (08/31, Classic Double)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 139/157 The Signature Hoi An | Signature Lantern Room | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [The Signature Hoi ] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [The Signature Hoi ] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⛔ [The Signature Hoi ] W2 08/03: blocked 2× in a row → skip rest of hotel (fast NA; cooldown rounds retry later)
#       ❌ [The Signature Hoi An] W1: NA
#       ❌ [The Signature Hoi An] W3: NA
#       ❌ [The Signature Hoi An] W4: NA
#       ❌ [The Signature Hoi An] W5: NA
#       ❌ [The Signature Hoi An] W6: NA
#       ❌ [The Signature Hoi An] W2: NA
#    ⚠️ 0/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 140/157 Topas Ecolodge | Deluxe Suite | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Topas Ecolodge] W1: 9,686,412 (07/27, Deluxe Suite)
#       ✅ [Topas Ecolodge] W2: 9,679,195 (08/03, Deluxe Suite)
#       ✅ [Topas Ecolodge] W3: 9,686,412 (08/10, Deluxe Suite)
#       ✅ [Topas Ecolodge] W4: 9,679,195 (08/17, Deluxe Suite)
#       ✅ [Topas Ecolodge] W5: 9,679,195 (08/24, Deluxe Suite)
#       ✅ [Topas Ecolodge] W6: 10,414,814 (08/31, Deluxe Suite)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 141/157 Tui ba gang - Deluxe Plus | Deluxe Plus | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Tui ba gang - Deluxe P] W2: 1,347,247 (08/03, Deluxe Plus)
#       ✅ [Tui ba gang - Deluxe P] W3: 1,347,247 (08/10, Deluxe Plus)
#       ✅ [Tui ba gang - Deluxe P] W4: 979,816 (08/17, Deluxe Plus)
#       ✅ [Tui ba gang - Deluxe P] W5: 979,816 (08/24, Deluxe Plus)
#       ✅ [Tui ba gang - Deluxe P] W6: 1,959,632 (08/31, Deluxe Plus)
#       ✅ [Tui ba gang - Deluxe P] W1: 1,347,247 (07/30, Deluxe Plus)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 142/157 Tui ba gang - Phòng Đẳng Cấp – 1 Giường (Premier Room - 1 Bed) | Phòng Đẳng Cấp – 1 Giường (Premier Room - 1 Bed) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Tui ba gang - Phòng Đẳ] W2: 1,592,201 (08/03, Phòng Đẳng Cấp – 1 G)
#       ✅ [Tui ba gang - Phòng Đẳ] W3: 1,592,201 (08/10, Phòng Đẳng Cấp – 1 G)
#       ✅ [Tui ba gang - Phòng Đẳ] W4: 952,412 (08/17, Phòng Đẳng Cấp – 1 G)
#       ✅ [Tui ba gang - Phòng Đẳ] W5: 1,102,293 (08/24, Phòng Đẳng Cấp – 1 G)
#       ✅ [Tui ba gang - Phòng Đẳ] W6: 2,327,063 (08/31, Phòng Đẳng Cấp – 1 G)
#       ✅ [Tui ba gang - Phòng Đẳ] W1: 1,592,201 (07/30, Phòng Đẳng Cấp – 1 G)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 143/157 Tui ba gang - Phòng Gia Đình Loại Sang (Deluxe Family Room) | Phòng Gia Đình Loại Sang (Deluxe Family Room) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Tui ba gang - Phòng Gi] W2: 1,553,947 (08/03, Phòng Gia Đình Loại )
#       ✅ [Tui ba gang - Phòng Gi] W3: 2,204,586 (08/10, Phòng Gia Đình Loại )
#       ✅ [Tui ba gang - Phòng Gi] W4: 1,775,916 (08/17, Phòng Gia Đình Loại )
#       ✅ [Tui ba gang - Phòng Gi] W5: 1,775,916 (08/24, Phòng Gia Đình Loại )
#       ✅ [Tui ba gang - Phòng Gi] W6: 2,816,971 (08/31, Phòng Gia Đình Loại )
#       ✅ [Tui ba gang - Phòng Gi] W1: 2,204,586 (07/30, Phòng Gia Đình Loại )
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 144/157 Tui ba gang - Phòng Gia đình với Ban công Riêng (Family Room with Private Balcony) | Phòng Gia đình với Ban công Riêng (Family Room with Private Balcony) | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [Tui ba gang - Phòn] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Tui ba gang - Phòn] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [Tui ba gang - Phòng Gi] W1: 2,449,540 (07/30, Phòng Gia đình với B)
#       ✅ [Tui ba gang - Phòng Gi] W2: 1,668,421 (08/03, Phòng Gia đình với B)
#       ✅ [Tui ba gang - Phòng Gi] W3: 2,449,540 (08/10, Phòng Gia đình với B)
#       ✅ [Tui ba gang - Phòng Gi] W4: 2,020,870 (08/17, Phòng Gia đình với B)
#       ✅ [Tui ba gang - Phòng Gi] W5: 2,020,870 (08/24, Phòng Gia đình với B)
#       ✅ [Tui ba gang - Phòng Gi] W6: 3,061,925 (08/31, Phòng Gia đình với B)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 145/157 Tui ba gang - Phòng Loại Sang - 1 Giường (Deluxe Room -- 1 Bed) | Phòng Loại Sang - 1 Giường (Deluxe Room -- 1 Bed) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Tui ba gang - Phòng Lo] W2: 1,102,293 (08/03, Phòng Loại Sang - 1 )
#       ✅ [Tui ba gang - Phòng Lo] W3: 1,102,293 (08/10, Phòng Loại Sang - 1 )
#       ✅ [Tui ba gang - Phòng Lo] W4: 857,339 (08/17, Phòng Loại Sang - 1 )
#       ✅ [Tui ba gang - Phòng Lo] W5: 857,339 (08/24, Phòng Loại Sang - 1 )
#       ✅ [Tui ba gang - Phòng Lo] W6: 1,714,678 (08/31, Phòng Loại Sang - 1 )
#       ✅ [Tui ba gang - Phòng Lo] W1: 1,102,293 (07/30, Phòng Loại Sang - 1 )
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 146/157 Tui ba gang - Phòng Trip (Trip Room) | Phòng Trip (Trip Room) | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [Tui ba gang - Phòn] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Tui ba gang - Phòn] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [Tui ba gang - Phòng Tr] W2: 1,253,509 (08/03, Phòng Trip (Trip Roo)
#       ✅ [Tui ba gang - Phòng Tr] W3: 1,775,916 (08/10, Phòng Trip (Trip Roo)
#       ⟳ [Tui ba gang - Phòn] W1 07/28: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Tui ba gang - Phòn] W4 08/17: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [Tui ba gang - Phòng Tr] W4: 1,253,509 (08/17, Phòng Trip (Trip Roo)
#       ✅ [Tui ba gang - Phòng Tr] W5: 1,408,485 (08/24, Phòng Trip (Trip Roo)
#       ✅ [Tui ba gang - Phòng Tr] W6: 2,388,301 (08/31, Phòng Trip (Trip Roo)
#       ✅ [Tui ba gang - Phòng Tr] W1: 1,775,916 (07/30, Phòng Trip (Trip Roo)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 147/157 Túi Ba Gang Central Hotel | Deluxe Room -- 1 Bed | need weeks [1, 2, 3, 4, 5, 6]
#       ⟳ [Túi Ba Gang Centra] W2 08/03: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Túi Ba Gang Centra] W1 07/27: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ✅ [Túi Ba Gang Central Ho] W2: 1,102,293 (08/03, Deluxe Room -- 1 Bed)
#       ✅ [Túi Ba Gang Central Ho] W3: 1,102,293 (08/10, Deluxe Room -- 1 Bed)
#       ✅ [Túi Ba Gang Central Ho] W4: 857,339 (08/17, Deluxe Room -- 1 Bed)
#       ✅ [Túi Ba Gang Central Ho] W5: 857,339 (08/24, Deluxe Room -- 1 Bed)
#       ✅ [Túi Ba Gang Central Ho] W6: 1,714,678 (08/31, Deluxe Room -- 1 Bed)
#       ✅ [Túi Ba Gang Central Ho] W1: 1,102,293 (07/30, Deluxe Room -- 1 Bed)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 148/157 Vedana Lagoon Wellness Resort & Spa - 2 Bedrooms Lagoon View Villa with Free Afternoon Cocktail | 2 Bedrooms Lagoon View Villa with Free Afternoon Cocktail | need weeks [1, 2, 3, 4, 5, 6]
#       🚫 [Vedana Lagoon Wellness] W1: SOLD OUT
#       🚫 [Vedana Lagoon Wellness] W2: SOLD OUT
#       ⟳ [Vedana Lagoon Well] W3 08/12: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Vedana Lagoon Well] W4 08/19: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Vedana Lagoon Well] W4 08/22: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Vedana Lagoon Well] W3 08/15: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       🚫 [Vedana Lagoon Wellness] W3: SOLD OUT
#       🚫 [Vedana Lagoon Wellness] W4: SOLD OUT
#       ⟳ [Vedana Lagoon Well] W6 09/05: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       ⟳ [Vedana Lagoon Well] W5 08/29: soft-blocked (empty rooms/camoufox) — retry 2/2…
#       🚫 [Vedana Lagoon Wellness] W6: SOLD OUT
#       🚫 [Vedana Lagoon Wellness] W5: SOLD OUT
#    ⚠️ 0/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 149/157 Vedana Lagoon Wellness Resort & Spa - Biệt Thự Hồ Bơi 2 Phòng Ngủ Hướng Đầm Phá - Miễn Phí Cocktail Buổi Chiều (2 Bedrooms Lagoon View Pool Villa - Free afternoon cocktail) | Biệt Thự Hồ Bơi 2 Phòng Ngủ Hướng Đầm Phá - Miễn Phí Cocktail Buổi Chiều (2 Bedrooms Lagoon View Pool Villa - Free afternoon cocktail) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Vedana Lagoon Wellness] W2: 8,252,768 (08/07, Biệt Thự Hồ Bơi 2 Ph)
#       ✅ [Vedana Lagoon Wellness] W3: 10,819,364 (08/10, Biệt Thự Hồ Bơi 2 Ph)
#       ✅ [Vedana Lagoon Wellness] W4: 8,249,552 (08/17, Biệt Thự Hồ Bơi 2 Ph)
#       🚫 [Vedana Lagoon Wellness] W1: SOLD OUT
#       ✅ [Vedana Lagoon Wellness] W5: 8,324,123 (08/24, Biệt Thự Hồ Bơi 2 Ph)
#       ✅ [Vedana Lagoon Wellness] W6: 8,334,683 (08/31, Biệt Thự Hồ Bơi 2 Ph)
#    ⚠️ 5/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 150/157 Vedana Lagoon Wellness Resort & Spa - Biệt Thự Trên Mặt Nước Có Hồ Bơi - Cocktail Chiều Miễn Phí (Water Pool Villa - Free afternoon cocktail) | Biệt Thự Trên Mặt Nước Có Hồ Bơi - Cocktail Chiều Miễn Phí (Water Pool Villa - Free afternoon cocktail) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Vedana Lagoon Wellness] W1: 7,423,224 (07/27, Biệt Thự Trên Mặt Nư)
#       ✅ [Vedana Lagoon Wellness] W2: 7,388,867 (08/03, Biệt Thự Trên Mặt Nư)
#       ✅ [Vedana Lagoon Wellness] W3: 7,387,971 (08/10, Biệt Thự Trên Mặt Nư)
#       ✅ [Vedana Lagoon Wellness] W4: 7,427,030 (08/18, Biệt Thự Trên Mặt Nư)
#       ✅ [Vedana Lagoon Wellness] W5: 7,483,597 (08/24, Biệt Thự Trên Mặt Nư)
#       ✅ [Vedana Lagoon Wellness] W6: 7,494,774 (08/31, Biệt Thự Trên Mặt Nư)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 151/157 Vedana Lagoon Wellness Resort & Spa - Hillside Biệt thự Có hồ bơi (Hillside Pool Villa) | Hillside Biệt thự Có hồ bơi (Hillside Pool Villa) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Vedana Lagoon Wellness] W1: 4,833,482 (07/27, Hillside Biệt thự Có)
#       ✅ [Vedana Lagoon Wellness] W2: 4,831,586 (08/03, Hillside Biệt thự Có)
#       ✅ [Vedana Lagoon Wellness] W3: 4,835,382 (08/10, Hillside Biệt thự Có)
#       ✅ [Vedana Lagoon Wellness] W4: 4,974,592 (08/17, Hillside Biệt thự Có)
#       ✅ [Vedana Lagoon Wellness] W5: 4,837,426 (08/24, Hillside Biệt thự Có)
#       ✅ [Vedana Lagoon Wellness] W6: 4,876,457 (08/31, Hillside Biệt thự Có)
#    ✅ 6/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 152/157 Vedana Lagoon Wellness Resort & Spa - Villa bên hồ (Water Villa) | Villa bên hồ (Water Villa) | need weeks [1, 2, 3, 4, 5, 6]
#       ✅ [Vedana Lagoon Wellness] W1: 4,833,482 (07/27, Villa bên hồ (Water )
#       ✅ [Vedana Lagoon Wellness] W2: 3,693,262 (08/03, Villa bên hồ (Water )
#       🚫 [Vedana Lagoon Wellness] W3: SOLD OUT
#       🚫 [Vedana Lagoon Wellness] W4: SOLD OUT
#       🚫 [Vedana Lagoon Wellness] W6: SOLD OUT
#       🚫 [Vedana Lagoon Wellness] W5: SOLD OUT
#    ⚠️ 2/6 priced (direct 0, fallback 6) | pace limit=1
#
# 🏨 153/157 Vedana Lagoon Wellness Resort & Spa - Villa cạnh đồi (Hillside Villa) | Villa cạnh đồi (Hillside Villa) | need weeks [1, 2, 3, 4, 5, 6]

# %%
# ════════════════ ④ XEM KẾT QUẢ ════════════════
import glob
import pandas as pd

OUTDIR = os.path.join(ROOT, "results", "agoda", RUN_NAME)
files = sorted(glob.glob(os.path.join(OUTDIR, "FINAL_*.csv")))
assert files, "Chưa có file FINAL nào — hãy chạy cell ③ trước."
latest = files[-1]
df = pd.read_csv(latest)
print(f"📄 {latest} — {len(df)} dòng")
df.head(20)
